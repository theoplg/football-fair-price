# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Visualization

# %%
# 1. Charger tes données propres
df = pd.read_csv('../data/processed/transfers_cleaned.csv')

# 2. Voir un aperçu
display(df.head())

# 3. GRAPHIQUE 1 : Le Prix selon le Poste
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Position_Encoded', y='Prix')
plt.title("Distribution des prix par poste (1=Gardien, 4=Attaquant)")
plt.show()

# 4. GRAPHIQUE 2 : Corrélation Age / Prix
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Age', y='Prix', hue='Position_Encoded')
plt.title("Prix selon l'âge")
plt.show()
# Out:
#                  Nom  Age  Position_Encoded  Valeur_Marchande  Matchs_22_23  \
# 0    Jude Bellingham   22               3.0       120000000.0            42
# 1        Declan Rice   27               3.0        90000000.0            50
# 2     Moisés Caicedo   24               3.0        75000000.0            43
# 3         Harry Kane   32               4.0        90000000.0            49
# 4  Randal Kolo Muani   27               4.0        80000000.0            46
#
#    Buts_22_23  Minutes_22_23         Prix
# 0          14           3557  127000000.0
# 1           5           4148  116600000.0
# 2           1           3666  116000000.0
# 3          32           4303   95000000.0
# 4          23           3634   95000000.0
